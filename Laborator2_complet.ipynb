# %%
import numpy as np
import matplotlib.pyplot as plt

#laborator2

#exercitiul1

amplitudine = 1.0
frecventa = 2.0
faza = 0

t = np.linspace(0, 2, 1000)
semnal_sinus = amplitudine * np.sin(2 * np.pi * frecventa * t + faza)
semnal_cosinus = amplitudine * np.cos(2 * np.pi * frecventa * t + faza - np.pi/2)

fig, axs = plt.subplots(2)
fig.suptitle('Exercitiul 1')
axs[0].plot(t,semnal_sinus)
axs[1].plot(t,semnal_cosinus)

plt.show()

# %%
import numpy as np
import random
import math
import matplotlib.pyplot as plt

#laborator2

#exercitiul2

amplitudine = 1.0
frecventa = 2.0
faza1 = 0
faza2 = 1
faza3 = 2
faza4 = 4

t = np.linspace(0, 2, 1000)
x1 = amplitudine * np.sin(2 * np.pi * frecventa * t + faza1)
x2 = amplitudine * np.sin(2 * np.pi * frecventa * t + faza2)
x3 = amplitudine * np.sin(2 * np.pi * frecventa * t + faza3)
x4 = amplitudine * np.sin(2 * np.pi * frecventa * t + faza4)


fig, axs = plt.subplots(4)
fig.suptitle('Exercitiul 2')
axs[0].plot(t,semnal_sinus_1)
axs[1].plot(t,semnal_sinus_2)
axs[2].plot(t,semnal_sinus_3)
axs[3].plot(t,semnal_sinus_4)

# plt.plot(t,x1)
# plt.plot(t,x2)
# plt.plot(t,x3)
# plt.plot(t,x4)

# plt.show()

z=np.random.normal(0, 1, 4)
snr=[0.1,1,10,100]

semnale_zgomot = []
for item in snr:
  gama = math.sqrt(np.linalg.norm(x1)**2 / (item * np.linalg.norm(z)**2))
  semnal_zgomot = x1 + gama * z
  semnale_zgomot.append(semnal_zgomot)

plt.figure(figsize=(10, 6))
for i, semnal_zgomot in enumerate(semnale_zgomot):
    plt.plot(t, semnal_zgomot)


# gama1_x1=math.sqrt( pow(np.linalg.norm(x1,2),2) / (snr1*pow(np.linalg.norm(z,2),2)) )
# gama2_x1=math.sqrt( pow(np.linalg.norm(x1,2),2) / (snr2*pow(np.linalg.norm(z,2),2)) )
# gama3_x1=math.sqrt( pow(np.linalg.norm(x1,2),2) / (snr3*pow(np.linalg.norm(z,2),2)) )
# gama4_x1=math.sqrt( pow(np.linalg.norm(x1,2),2) / (snr4*pow(np.linalg.norm(z,2),2)) )


# print("z",gama1_x1)
# semnal_gama1_x1_z1 = x1+(gama1_x1*z[0])
# semnal_gama1_x1_z2 = x1+(gama1_x1*z[1])
# semnal_gama1_x1_z3 = x1+(gama1_x1*z[2])
# semnal_gama1_x1_z4 = x1+(gama1_x1*z[3])

# plt.plot(t,semnal_gama1_x1_z1)
# plt.plot(t,semnal_gama1_x1_z2)
# plt.plot(t,semnal_gama1_x1_z3)
# plt.plot(t,semnal_gama1_x1_z4)


#linalg.norm
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-f4f945ceb875> in <cell line: 42>()
#      42 for item in snr:
#      43   gama = math.sqrt(np.linalg.norm(x1)**2 / (item * np.linalg.norm(z)**2))
# ---> 44   semnal_zgomot = x1 + gama * z
#      45   semnale_zgomot.append(semnal_zgomot)
#      46
#
# ValueError: operands could not be broadcast together with shapes (1000,) (4,)

# %%
from numpy.lib.npyio import NpzFile
import numpy as np
import random
import math
import matplotlib.pyplot as plt

#laborator2

#exercitiul4

import numpy as np
import matplotlib.pyplot as plt

amplitudine_sinus = 1.0
frecventa_sinus = 2.0
faza_sinus = 0.0

amplitudine_sawtooth = 0.8
frecventa_sawtooth = 1.0
faza_sawtooth = 0.0

t = np.linspace(0, 1500, 3)

semnal_sinus = amplitudine_sinus * np.sin(2 * np.pi * frecventa_sinus * t + faza_sinus)
semnal_sawtooth = 2 * (t - np.floor(t+0.5))

suma_semnalelor = semnal_sinus + semnal_sawtooth

plt.figure(figsize=(10, 6))

plt.subplot(3, 1, 1)
plt.plot(t, semnal_sinus)
plt.title('Semnal Sinusoidal')
plt.legend()
plt.subplot(3, 1, 2)
plt.plot(t, semnal_sawtooth, color='red')
plt.title('Semnal Sawtooth')

plt.subplot(3, 1, 3)
plt.plot(t, suma_semnalelor, color='green')
plt.title('Suma Semnalelor')

plt.tight_layout()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
from numpy.lib.npyio import NpzFile
import numpy as np
import random
import math
import matplotlib.pyplot as plt
import sounddevice as sd

#laborator2

#exercitiul5

amplitudine = 0.7
frecventa1 = 370
frecventa2 = 550
durata = 2

t = np.linspace(0, 1500, 3)
semnal1 = amplitudine * np.sin(2 * np.pi * frecventa1 * t)
semnal2 = amplitudine * np.sin(2 * np.pi * frecventa2 * t)

semnal = np.concatenate((semnal1, semnal2))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-19-334cf555f1a7> in <cell line: 6>()
#       4 import math
#       5 import matplotlib.pyplot as plt
# ----> 6 import sounddevice as sd
#       7
#       8 #laborator2
#
# ModuleNotFoundError: No module named 'sounddevice'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import numpy as np
import matplotlib.pyplot as plt

#laborator2

#exercitiul5

fs = 1000

t = np.linspace(0, 1000, 3)
fa = fs / 2
fb = fs / 4
fc = 0

semnala = np.sin(2 * np.pi * fa * t)
semnalb = np.sin(2 * np.pi * fb * t)
semnalc = np.sin(2 * np.pi * fc * t)

fig, axs = plt.subplots(3)
fig.suptitle('Exercitiul 6')
axs[0].plot(t,semnala)
axs[1].plot(t,semnalb)
axs[2].plot(t,semnalc)

plt.show()
